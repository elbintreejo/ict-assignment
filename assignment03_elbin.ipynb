# %% [markdown]
# <a href="https://colab.research.google.com/github/elbintreejo/ict-assignment/blob/main/assignment03_elbin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python function to find the Max of three numbers

# %%
n = (23,24,25)
max(n)
# Out:
# 25

# %% [markdown]
# 2. Write a Python function to sum all the numbers in a list.

# %%
def sum_list(items):
    sum = 0
    for x in items:
        sum += x
    return sum
print(sum_list([18, 12, 30, 10, 7]))
# Out:
# 77

# %% [markdown]
# 3. Python program to insert a number to any position in a list (Get the number
# to be inserted and position from the user)

# %%
list2 = [22,33,44,55,66,77]

# %%
list2.insert(3,777)

# %%
list2
# Out:
# [22, 33, 44, 777, 55, 66, 77]

# %% [markdown]
# 4. Write a program to rename a key city to a location in the following dictionary.

# %%
dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}
dict["location"] = dict.pop("city")
print(dict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %% [markdown]
# 5. Write a Python program to change Brad’s salary to 8500 in the following
# dictionary.

# %%
dict = {'emp1': {'name': 'Jhon', 'salary': 7500},'emp2': {'name': 'Emma', 'salary': 8000},'emp3': {'name': 'Brad', 'salary': 500}}
dict['emp3']['salary'] = 8500
print(dict)
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# 6. Write a program to copy elements 44 and 55 from the following tuple into a
# new tuple. Given: tuple1 = (11, 22, 33, 44, 55, 66)

# %%
tuple1 = (11, 22, 33, 44, 55, 66)
new_tuple = (tuple1[3], tuple1[4])
print(new_tuple)
# Out:
# (44, 55)

# %% [markdown]
# 7. Counts the number of occurrences of item 50 from a tuple tuple1 = (50, 10,
# 60, 70, 50,83,567,50,81)

# %%
tuple1 = (50, 10, 60, 70, 50, 83, 567, 50, 81)
count = tuple1.count(50)
print("The number of occurrences of 50 in the tuple is: ",count)
# Out:
# The number of occurrences of 50 in the tuple is:  3
