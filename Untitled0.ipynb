# %% [markdown]
# <a href="https://colab.research.google.com/github/elbintreejo/ict-assignment/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nested data structure for the question bank
QUESTION_BANK = {
    "Easy": {
        "Q1": {
            "question": "What is the capital of France?",
         if  : "PARIS"
           print('answer is correct')
         else
           print('answer is incorrect')
        },
        "Q2": {
            "question": "How many legs does a spider have?",
            "answer": "8"
        }
    },
    "Medium": {
        "Q1": {
            "question": "Which planet is known as the Red Planet?",
            "answer": "MARS"
        },
        "Q2": {
            "question": "Who painted the Mona Lisa?",
            "answer": "LEONARDO DA VINCI"
        }
    },
    "Hard": {
        "Q1": {
            "question": "What is the square root of 225?",
            "answer": "15"
        },
        "Q2": {
            "question": "Name the largest organ in the human body?",
            "answer": "SKIN"
        }
    }
}

# %%
Q1

# %%
# Nested data structure for the qu
print('EASY')
question =input('What is the capital of France?')
if (question== "PARIS"):
   print('answer is correct')
else:
   print('answer is incorrect')
print('MEDIUM')
question =input('how many leg does have a spider?')
if (question== "8"):
  print('answer is correct')
else:
  print ('answer is incorrect')
print('hard')
question =input('what is the square root of 225?')
if  (question== "15"):
   print('answer is correct')
else:
   print('answer is incorrect')
# Out:
# EASY
# What is the capital of France?PARIS
# answer is correct
# MEDIUM
# how many leg does have a spider?8
# answer is correct
# hard
# what is the square root of 225?15
# answer is correct
