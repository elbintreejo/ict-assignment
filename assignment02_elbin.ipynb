# %% [markdown]
# <a href="https://colab.research.google.com/github/elbintreejo/ict-assignment/blob/main/assignment02_elbin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1

# %%
n=int(input("enter a number"))
if n%3==0 and n%5==0:
 print("fizzbuzz")
elif n%3==0:
 print("fizz")
elif n%5==0:
 print("buzz")
else:
 print(n)
# Out:
# enter a number5
# buzz

# %% [markdown]
# 2

# %%
n=int(input("enter the number of unit consumed : "))
totalamount = 0

if n <=100:
 totalamount = n*5
elif n <= 200:
 totalamount = (100*5) + (n-100) * 7
else:
 totalamount = (100*5) + (100*7)+((n-200)*10)
 print(f"Total Bill amount :{totalamount}")
# Out:
# enter the number of unit consumed : 245
# Total Bill amount :1650

# %%
for i in range(1,6):
 print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
pal=str(input("Enter num or string to be checked:"))
rev_pal = pal[::-1]

if rev_pal == pal:
 print(pal,"palindrome")
else:
 print(pal,"not palindrome")
# Out:
# Enter num or string to be checked:121
# 121 palindrome
